# %% [markdown]
# Logging with multiple loggers
#
# We can create multiple loggers for different parts of our application

# %%
import logging

# %%
logger1 = logging.getLogger("module1")
logger1.setLevel(logging.DEBUG)

logger2 = logging.getLogger("module2")
logger2.setLevel(logging.WARNING)

logging.basicConfig(
    level=logging.DEBUG,
    format="%(asctime)s - %(name)s - %(levelname)s - %(message)s",
    datefmt="%Y-%M-%D %H:%M:%S",
)

# %%
logger1.debug("This is a debug message for logger 1")
logger2.warning("this is a warning message for module 2")
logger2.error("Error message")
# Out:
# 2026-37-05/24/26 18:37:39 - module1 - DEBUG - This is a debug message for logger 1
# 2026-37-05/24/26 18:37:39 - module2 - WARNING - this is a warning message for module 2
# 2026-37-05/24/26 18:37:39 - module2 - ERROR - Error message
