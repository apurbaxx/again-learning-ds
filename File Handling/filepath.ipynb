# %%
##Create a new directory
import os
new_dir = "pakage"
os.mkdir(new_dir)
print(f"Directory {new_dir} created")
# Out:
# Directory pakage created

# %%
#listing Files and directories

items = os.listdir(".")
print(items)
# Out:
# ['example.txt', 'fileoperation.ipynb', 'filepath.ipynb', 'pakage']

# %%
##Joining paths

dir_name = "pakage"
file_name = "file.txt"
full_path = os.path.join(os.getcwd(), dir_name, file_name)
print(full_path)
# Out:
# C:\Users\apurb\Documents\VIT\Learning\Data Science\File Handling\pakage\file.txt
