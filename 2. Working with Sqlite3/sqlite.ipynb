# %% [markdown]
# SQL AND SQLite
#
# SQL (Structured Query Language) is a standard language for managing and manipulating relational databases. SQLite is self-contained,serverless, and zero configuration database engine that is widely used for embedded database systems.

# %%
import _sqlite3

# %%
##Connect to an sqlite database

connection = _sqlite3.connect("example.db")
connection

# %%
cursor = connection.cursor()

# %%
cursor.execute('''
Create Table If Not Exists employees(
            id Integer Primary Key,
            name text Not Null,
            age Integer,
            department Text
)
''')

##commit the changes
connection.commit()

# %%
cursor.execute('''
Select * from employees
''')

# %%
##Insert the data in sqlite3

cursor.execute('''
Insert Into employees(name,age,department)
    Values("Apurba", "19", "Data Scientist")
''')

cursor.execute('''
Insert Into employees(name,age,department)
    Values("Bob", "20", "Engeneering")
''')

cursor.execute('''
Insert Into employees(name,age,department)
    Values("John", "30", "Finance")
''')

connection.commit()

# %%
##Query the data from the table

cursor.execute("Select * from employees")
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (1, 'Apurba', 19, 'Data Scientist')
# (2, 'Bob', 20, 'Engeneering')
# (3, 'John', 30, 'Finance')
# (4, 'Apurba', 19, 'Data Scientist')
# (5, 'Bob', 20, 'Engeneering')
# (6, 'John', 30, 'Finance')
# (7, 'Apurba', 19, 'Data Scientist')
# (8, 'Bob', 20, 'Engeneering')
# (9, 'John', 30, 'Finance')

# %%
##Update data in the table

cursor.execute(
    '''
    Update employees
    Set age = 34
        where name = "Apurba"
    '''
)

connection.commit()

# %%
cursor.execute("Select * from employees")
rows = cursor.fetchall()
for row in rows:
    print(row)
# Out:
# (1, 'Apurba', 34, 'Data Scientist')
# (2, 'Bob', 20, 'Engeneering')
# (3, 'John', 30, 'Finance')
# (4, 'Apurba', 34, 'Data Scientist')
# (5, 'Bob', 20, 'Engeneering')
# (6, 'John', 30, 'Finance')
# (7, 'Apurba', 34, 'Data Scientist')
# (8, 'Bob', 20, 'Engeneering')
# (9, 'John', 30, 'Finance')

# %%
##Delete the data from the table
cursor.execute('''
Delete from employees
    where name = "Bob"
''')
connection.commit()

# %%
cursor.execute("Select * from employees")
rows = cursor.fetchall()
for row in rows:
    print(row)
# Out:
# (1, 'Apurba', 34, 'Data Scientist')
# (3, 'John', 30, 'Finance')
# (4, 'Apurba', 34, 'Data Scientist')
# (6, 'John', 30, 'Finance')
# (7, 'Apurba', 34, 'Data Scientist')
# (9, 'John', 30, 'Finance')
